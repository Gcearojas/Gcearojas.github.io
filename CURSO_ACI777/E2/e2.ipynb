# %% [markdown]
# Nombre: Gustavo Anibal Cea Rojas fechas:20 de octubre 2021

# %% [markdown]
# Definiendo el Ejercicio 2.
# Instrucciones
# A cada alumno se le asignó en el ejercicio 1 un conjunto de datos en formato CSV
#
# Deberá:
#
# Crear una carpeta nueva en su repositorio git con el nombre E2 (0.2 pto)
# Dentro de E2 crear una carpeta que se llame data. (0.2 pto)
# Guardar los datos asignados en esa carpeta. (0.2 pto)
# Dentro de E2 debera crear un Jupyter Notebook llamado E2. (0.2 pto)
# En el Jupyter Notebook, configurar la primera casilla en Lenguaje Markdown y escribir su nombre, fecha, y esta lista de instrucciones de forma ordenada. (0.2 pts)
# Importar la librería pandas de python para poder procesar y graficar los datos del archivo. Utilizar describe, shape e indicar para que se utilizan estos comandos y que puede deducir de esta información. Debe separar el código en las casillas que estime conveniente, pero se solicita minimo que en una casilla esten solo las importaciones, en otra solo la lectura de los datos y otra con los plots, además cada casilla debe tener una casilla previa que describa el código en formato markdown. (3 pts)
# Hacer los gráficos correspondientes al conjunto de datos seleccionado. (1 pts)
# Utilizar los comandos adecuados de git para actualizar su repositorio y dejarlo disponible en github de forma pública. (1 pts)
# La nota será calculada de la siguiente manera:
#
# NOTA FINAL = Puntaje + 1
#
# ⚠️ Bonus Track, pueden usar la librería seaborn para embellecer sus gráficos de matplotlib. (0.5 pts)

# %% [markdown]
# Primero importamos pandas y matplot

# %%
import pandas as pan
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

# %% [markdown]
# luego hay que leer los datos del csv y colocar el salto entre los datos en este caso ','

# %%
datoscsv=pan.read_csv('data/ResidenciasSanitarias.csv')
datoscsv=datoscsv[datoscsv.Categoria !=',']

# %% [markdown]
# quitaremos de los datos la fecha 2020-06-01 la cual no tienes datos y ademas elimaneros la columna categoria para que luego no de problemas al graficarla

# %%
datoscsv=datoscsv.drop(['2020-06-01'], axis=1)

# %%
datoscsv=datoscsv.drop(['Categoria'], axis=1)

# %% [markdown]
# eliminaremos los datos de la tabla que no nos importan en este caso

# %%
datoscsv=datoscsv.drop(range(0, 32, 1),axis=0)

# %% [markdown]
# revisamos que los datos fueran eliminados

# %%
datoscsv
# Out:
#                 Region  2020-05-29  2020-05-30  2020-05-31  2020-06-02  \
# 32  Arica y Parinacota           1           1           1           1
# 33            Tarapacá           2           2           4           4
# 34         Antofagasta           3           3           3           3
# 35             Atacama           2           2           2           2
# 36            Coquimbo           6           6           6           6
# 37          Valparaíso           7           7           8           8
# 38       Metropolitana          32          32          31          30
# 39           O’Higgins           2           2           2           2
# 40               Maule           2           2           3           4
# 41               Ñuble           2           2           2           2
# 42              Biobío           5           5           7           9
# 43           Araucanía           2           2           2           3
# ...

# %% [markdown]
# Ahora colocaremos la columna region como el indice

# %%
datoscsv.set_index(['Region'], inplace=True)

# %%
datoscsv
# Out:
#                     2020-05-29  2020-05-30  2020-05-31  2020-06-02  \
# Region
# Arica y Parinacota           1           1           1           1
# Tarapacá                     2           2           4           4
# Antofagasta                  3           3           3           3
# Atacama                      2           2           2           2
# Coquimbo                     6           6           6           6
# Valparaíso                   7           7           8           8
# Metropolitana               32          32          31          30
# O’Higgins                    2           2           2           2
# Maule                        2           2           3           4
# Ñuble                        2           2           2           2
# Biobío                       5           5           7           9
# Araucanía                    2           2           2           3
# Los Ríos                     6           6           5           4
# ...

# %% [markdown]
# Ahora probamos que los datos se grafiquen correctamente

# %%
datoscsv.T.plot(figsize=(30,15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Leer datos csv y colocar la separacion con ','

# %%
datoscsv2=pan.read_csv('data/ResidenciasSanitarias.csv')
datoscsv2=datoscsv2[datoscsv2.Categoria !=',']

# %% [markdown]
# Eliminamos las columnas 2020-06-01 y categoria para trabajar de mejor manera con los datos

# %%
datoscsv2=datoscsv2.drop(['2020-06-01'], axis=1)
datoscsv2=datoscsv2.drop(['Categoria'], axis=1)

# %% [markdown]
# quitamos las filas de residencias y cupos totales ya que nos piden unicamente usuarios en residencia

# %%
datoscsv2=datoscsv2.drop(range(0, 16, 1),axis=0)
datoscsv2=datoscsv2.drop(range(32, 48, 1),axis=0)

# %% [markdown]
# transformamos el indice por region y probamos que la tabla este correcta

# %%
datoscsv2.set_index(['Region'], inplace=True)

# %%
datoscsv2
# Out:
#                     2020-05-29  2020-05-30  2020-05-31  2020-06-02  \
# Region
# Arica y Parinacota          29          29          31          35
# Tarapacá                    32          32          45          76
# Antofagasta                 86          86          93          94
# Atacama                     34          34          32          44
# Coquimbo                    77          77          65          87
# Valparaíso                  71          71         121         157
# Metropolitana              706         706         842         949
# O’Higgins                    0           0           1           2
# Maule                       39          39          59          63
# Ñuble                       22          22          21          28
# Biobío                     119         119         139         135
# Araucanía                   89          89         113         130
# Los Ríos                    47          47           7           7
# ...

# %%
datoscsv2.T.plot(figsize=(30,15))
# Out:
# <AxesSubplot:>
